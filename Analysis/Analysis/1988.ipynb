# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1988.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1988                17287             42          34                3525
# 1     1988                17719            297          27                3563
# 2     1988                17389            309          17                3546
# 3     1988                17102             51          35                3501
# 4     1988                17976            301          22                3567
# ...    ...                  ...            ...         ...                 ...
# 1884  1988                17301            198          21                3500
# 1885  1988                17675            429          39                3560
# 1886  1988                17157            266          16                3504
# 1887  1988                17261            359          23                3512
# 1888  1988                17669            437          25                3500
#
# [1889 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1889, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889 entries, 0 to 1888
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1889 non-null   int64
#  1   Maximum length (m))  1889 non-null   int64
#  2   Recession(m),        1889 non-null   int64
#  3   Rate/yr(m)           1889 non-null   int64
#  4   Snout altitude (m)   1889 non-null   int64
# dtypes: int64(5)
# memory usage: 73.9 KB

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1889

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1988                17287             42          34                3525
# 1  1988                17719            297          27                3563
# 2  1988                17389            309          17                3546
# 3  1988                17102             51          35                3501
# 4  1988                17976            301          22                3567

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000        -0.0003      0.0157
# Recession(m),         NaN              -0.0003         1.0000      0.0252
# Rate/yr(m)            NaN               0.0157         0.0252      1.0000
# Snout altitude (m)    NaN               0.0240         0.0140     -0.0214
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))              0.0240
# Recession(m),                    0.0140
# Rate/yr(m)                      -0.0214
# Snout altitude (m)               1.0000

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,889.0000           1,889.0000     1,889.0000  1,889.0000  \
# mean  1,988.0000          17,557.7893       222.3171     27.5940
# std       0.0000             298.5558       127.0385      8.6118
# min   1,988.0000          17,035.0000         0.0000     13.0000
# 25%   1,988.0000          17,296.0000       110.0000     20.0000
# 50%   1,988.0000          17,553.0000       222.0000     28.0000
# 75%   1,988.0000          17,818.0000       333.0000     35.0000
# max   1,988.0000          18,067.0000       440.0000     42.0000
#
#        Snout altitude (m)
# count          1,889.0000
# mean           3,532.1615
# std               20.9848
# min            3,496.0000
# 25%            3,514.0000
# 50%            3,532.0000
# 75%            3,551.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1988   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 356   0.0058
# 304   0.0058
# 137   0.0053
# 127   0.0053
# 413   0.0053
#        ...
# 24    0.0005
# 9     0.0005
# 250   0.0005
# 291   0.0005
# 19    0.0005
# Name: count, Length: 434, dtype: float64
#
# Rate/yr(m)
# 26   0.0439
# 13   0.0413
# 18   0.0402
# 19   0.0386
# 29   0.0386
# 36   0.0381
# 33   0.0371
# 31   0.0365
# 34   0.0360
# 35   0.0360
# 42   0.0355
# 38   0.0339
# 24   0.0334
# 32   0.0328
# 22   0.0328
# 27   0.0323
# 25   0.0318
# 39   0.0318
# 14   0.0312
# 30   0.0312
# 40   0.0312
# 41   0.0307
# 21   0.0307
# 15   0.0302
# 23   0.0302
# 37   0.0286
# 20   0.0286
# 17   0.0270
# 28   0.0259
# 16   0.0238
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3499   0.0217
# 3554   0.0212
# 3566   0.0206
# 3512   0.0185
# 3515   0.0185
#         ...
# 3550   0.0085
# 3519   0.0085
# 3528   0.0074
# 3549   0.0069
# 3496   0.0021
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
