# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1996.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1996                17560            343          26                3505
# 1     1996                17688            254          18                3532
# 2     1996                17673             41          40                3555
# 3     1996                17282            288          40                3539
# 4     1996                17416             62          35                3554
# ...    ...                  ...            ...         ...                 ...
# 1877  1996                17461            398          34                3522
# 1878  1996                17191            340          32                3521
# 1879  1996                17313            203          38                3559
# 1880  1996                17300             40          40                3529
# 1881  1996                17617            311          39                3522
#
# [1882 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1882, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1882 entries, 0 to 1881
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1882 non-null   int64
#  1   Maximum length (m))  1882 non-null   int64
#  2   Recession(m),        1882 non-null   int64
#  3   Rate/yr(m)           1882 non-null   int64
#  4   Snout altitude (m)   1882 non-null   int64
# dtypes: int64(5)
# memory usage: 73.6 KB

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1882

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1996                17560            343          26                3505
# 1  1996                17688            254          18                3532
# 2  1996                17673             41          40                3555
# 3  1996                17282            288          40                3539
# 4  1996                17416             62          35                3554

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000        -0.0173     -0.0085
# Recession(m),         NaN              -0.0173         1.0000     -0.0115
# Rate/yr(m)            NaN              -0.0085        -0.0115      1.0000
# Snout altitude (m)    NaN              -0.0315        -0.0369     -0.0093
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))             -0.0315
# Recession(m),                   -0.0369
# Rate/yr(m)                      -0.0093
# Snout altitude (m)               1.0000

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,882.0000           1,882.0000     1,882.0000  1,882.0000  \
# mean  1,996.0000          17,556.6238       218.8310     27.5537
# std       0.0000             296.1891       129.2226      8.4589
# min   1,996.0000          17,035.0000         0.0000     13.0000
# 25%   1,996.0000          17,298.2500       106.0000     20.0000
# 50%   1,996.0000          17,565.0000       216.0000     28.0000
# 75%   1,996.0000          17,807.0000       334.0000     35.0000
# max   1,996.0000          18,067.0000       440.0000     42.0000
#
#        Snout altitude (m)
# count          1,882.0000
# mean           3,531.9272
# std               20.2838
# min            3,496.0000
# 25%            3,514.0000
# 50%            3,532.0000
# 75%            3,549.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1996   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 114   0.0069
# 210   0.0058
# 217   0.0058
# 416   0.0058
# 3     0.0058
#        ...
# 256   0.0005
# 206   0.0005
# 400   0.0005
# 402   0.0005
# 228   0.0005
# Name: count, Length: 432, dtype: float64
#
# Rate/yr(m)
# 29   0.0462
# 34   0.0425
# 38   0.0420
# 21   0.0409
# 20   0.0388
# 33   0.0367
# 26   0.0367
# 35   0.0356
# 23   0.0356
# 22   0.0340
# 15   0.0335
# 32   0.0335
# 18   0.0329
# 25   0.0324
# 27   0.0319
# 28   0.0313
# 40   0.0313
# 14   0.0313
# 17   0.0313
# 19   0.0308
# 36   0.0303
# 24   0.0303
# 37   0.0303
# 31   0.0303
# 42   0.0298
# 39   0.0298
# 13   0.0292
# 41   0.0282
# 30   0.0266
# 16   0.0260
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3549   0.0218
# 3512   0.0197
# 3541   0.0197
# 3498   0.0191
# 3525   0.0191
#         ...
# 3567   0.0096
# 3501   0.0096
# 3534   0.0090
# 3503   0.0085
# 3496   0.0005
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
