# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1993.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1993                17106            122          41                3545
# 1     1993                17978            433          18                3512
# 2     1993                17409            373          16                3525
# 3     1993                17562            112          36                3528
# 4     1993                17574            276          17                3554
# ...    ...                  ...            ...         ...                 ...
# 1814  1993                17283            119          32                3566
# 1815  1993                17198             10          38                3507
# 1816  1993                17116            222          38                3515
# 1817  1993                17964            149          34                3508
# 1818  1993                17142            194          28                3514
#
# [1819 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1819, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1819 entries, 0 to 1818
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1819 non-null   int64
#  1   Maximum length (m))  1819 non-null   int64
#  2   Recession(m),        1819 non-null   int64
#  3   Rate/yr(m)           1819 non-null   int64
#  4   Snout altitude (m)   1819 non-null   int64
# dtypes: int64(5)
# memory usage: 71.2 KB

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1819

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1993                17106            122          41                3545
# 1  1993                17978            433          18                3512
# 2  1993                17409            373          16                3525
# 3  1993                17562            112          36                3528
# 4  1993                17574            276          17                3554

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000         0.0151     -0.0213
# Recession(m),         NaN               0.0151         1.0000      0.0479
# Rate/yr(m)            NaN              -0.0213         0.0479      1.0000
# Snout altitude (m)    NaN              -0.0144        -0.0282      0.0103
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))             -0.0144
# Recession(m),                   -0.0282
# Rate/yr(m)                       0.0103
# Snout altitude (m)               1.0000

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,819.0000           1,819.0000     1,819.0000  1,819.0000  \
# mean  1,993.0000          17,554.8752       217.8571     27.7774
# std       0.0000             299.4736       127.6951      8.6298
# min   1,993.0000          17,035.0000         0.0000     13.0000
# 25%   1,993.0000          17,291.5000       111.0000     20.0000
# 50%   1,993.0000          17,559.0000       215.0000     28.0000
# 75%   1,993.0000          17,811.5000       330.5000     35.0000
# max   1,993.0000          18,066.0000       439.0000     42.0000
#
#        Snout altitude (m)
# count          1,819.0000
# mean           3,532.1622
# std               20.2822
# min            3,496.0000
# 25%            3,515.0000
# 50%            3,532.0000
# 75%            3,550.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1993   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 114   0.0066
# 304   0.0055
# 341   0.0055
# 395   0.0049
# 140   0.0049
#        ...
# 261   0.0005
# 33    0.0005
# 208   0.0005
# 316   0.0005
# 132   0.0005
# Name: count, Length: 433, dtype: float64
#
# Rate/yr(m)
# 31   0.0407
# 32   0.0396
# 28   0.0385
# 42   0.0379
# 19   0.0379
# 34   0.0368
# 38   0.0368
# 15   0.0357
# 18   0.0357
# 25   0.0357
# 21   0.0352
# 41   0.0352
# 36   0.0352
# 37   0.0346
# 29   0.0346
# 30   0.0341
# 13   0.0335
# 27   0.0324
# 33   0.0319
# 20   0.0313
# 39   0.0313
# 23   0.0313
# 40   0.0302
# 14   0.0302
# 24   0.0302
# 17   0.0286
# 26   0.0275
# 35   0.0264
# 22   0.0253
# 16   0.0253
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3559   0.0187
# 3531   0.0181
# 3530   0.0181
# 3520   0.0181
# 3523   0.0181
#         ...
# 3509   0.0104
# 3508   0.0099
# 3502   0.0093
# 3519   0.0060
# 3496   0.0011
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
