# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1995.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1995                17409            207          20                3498
# 1     1995                17542             24          32                3540
# 2     1995                17393             48          19                3501
# 3     1995                17578            306          40                3544
# 4     1995                17709            436          32                3559
# ...    ...                  ...            ...         ...                 ...
# 1892  1995                17511             73          37                3513
# 1893  1995                18030            299          16                3554
# 1894  1995                17411            423          26                3508
# 1895  1995                17447            338          42                3511
# 1896  1995                17664            378          25                3532
#
# [1897 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1897, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1897 non-null   int64
#  1   Maximum length (m))  1897 non-null   int64
#  2   Recession(m),        1897 non-null   int64
#  3   Rate/yr(m)           1897 non-null   int64
#  4   Snout altitude (m)   1897 non-null   int64
# dtypes: int64(5)
# memory usage: 74.2 KB

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1897

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1995                17409            207          20                3498
# 1  1995                17542             24          32                3540
# 2  1995                17393             48          19                3501
# 3  1995                17578            306          40                3544
# 4  1995                17709            436          32                3559

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000        -0.0506      0.0130
# Recession(m),         NaN              -0.0506         1.0000      0.0141
# Rate/yr(m)            NaN               0.0130         0.0141      1.0000
# Snout altitude (m)    NaN               0.0107        -0.0172      0.0187
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))              0.0107
# Recession(m),                   -0.0172
# Rate/yr(m)                       0.0187
# Snout altitude (m)               1.0000

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,897.0000           1,897.0000     1,897.0000  1,897.0000  \
# mean  1,995.0000          17,539.6231       219.1239     27.7248
# std       0.0000             297.5508       125.8494      8.6945
# min   1,995.0000          17,035.0000         0.0000     13.0000
# 25%   1,995.0000          17,283.0000       112.0000     20.0000
# 50%   1,995.0000          17,536.0000       219.0000     28.0000
# 75%   1,995.0000          17,794.0000       331.0000     35.0000
# max   1,995.0000          18,067.0000       440.0000     42.0000
#
#        Snout altitude (m)
# count          1,897.0000
# mean           3,530.6036
# std               20.4501
# min            3,496.0000
# 25%            3,512.0000
# 50%            3,531.0000
# 75%            3,548.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1995   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 286   0.0058
# 272   0.0053
# 380   0.0053
# 113   0.0053
# 115   0.0047
#        ...
# 430   0.0005
# 396   0.0005
# 85    0.0005
# 79    0.0005
# 206   0.0005
# Name: count, Length: 436, dtype: float64
#
# Rate/yr(m)
# 42   0.0411
# 14   0.0406
# 34   0.0380
# 40   0.0374
# 16   0.0374
# 38   0.0369
# 26   0.0369
# 27   0.0369
# 20   0.0364
# 30   0.0358
# 31   0.0353
# 33   0.0348
# 18   0.0343
# 29   0.0343
# 35   0.0332
# 24   0.0322
# 23   0.0322
# 39   0.0322
# 32   0.0316
# 25   0.0311
# 28   0.0311
# 21   0.0306
# 41   0.0300
# 37   0.0295
# 36   0.0295
# 17   0.0295
# 15   0.0295
# 22   0.0285
# 13   0.0285
# 19   0.0248
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3497   0.0206
# 3510   0.0200
# 3545   0.0190
# 3537   0.0190
# 3511   0.0185
#         ...
# 3561   0.0100
# 3556   0.0095
# 3563   0.0090
# 3558   0.0090
# 3496   0.0011
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
