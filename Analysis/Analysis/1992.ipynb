# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1992.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1992                17418              5          23                3564
# 1     1992                17134            159          25                3516
# 2     1992                17934            360          28                3535
# 3     1992                17690             43          27                3547
# 4     1992                17691            167          15                3560
# ...    ...                  ...            ...         ...                 ...
# 1835  1992                17806            126          20                3563
# 1836  1992                17536             69          42                3501
# 1837  1992                17185             65          17                3547
# 1838  1992                17077            277          26                3503
# 1839  1992                17290            372          34                3505
#
# [1840 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1840, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1840 entries, 0 to 1839
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1840 non-null   int64
#  1   Maximum length (m))  1840 non-null   int64
#  2   Recession(m),        1840 non-null   int64
#  3   Rate/yr(m)           1840 non-null   int64
#  4   Snout altitude (m)   1840 non-null   int64
# dtypes: int64(5)
# memory usage: 72.0 KB

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1840

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1992                17418              5          23                3564
# 1  1992                17134            159          25                3516
# 2  1992                17934            360          28                3535
# 3  1992                17690             43          27                3547
# 4  1992                17691            167          15                3560

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000         0.0110     -0.0080
# Recession(m),         NaN               0.0110         1.0000      0.0246
# Rate/yr(m)            NaN              -0.0080         0.0246      1.0000
# Snout altitude (m)    NaN               0.0319         0.0039     -0.0069
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))              0.0319
# Recession(m),                    0.0039
# Rate/yr(m)                      -0.0069
# Snout altitude (m)               1.0000

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,840.0000           1,840.0000     1,840.0000  1,840.0000  \
# mean  1,992.0000          17,561.1272       219.5375     27.3402
# std       0.0000             291.3787       128.5672      8.8280
# min   1,992.0000          17,035.0000         0.0000     13.0000
# 25%   1,992.0000          17,310.0000       109.7500     19.0000
# 50%   1,992.0000          17,568.0000       218.0000     27.0000
# 75%   1,992.0000          17,812.0000       332.0000     35.0000
# max   1,992.0000          18,067.0000       440.0000     42.0000
#
#        Snout altitude (m)
# count          1,840.0000
# mean           3,531.8641
# std               20.3248
# min            3,496.0000
# 25%            3,514.0000
# 50%            3,532.0000
# 75%            3,549.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1992   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 309   0.0060
# 11    0.0060
# 58    0.0054
# 433   0.0054
# 391   0.0054
#        ...
# 369   0.0005
# 267   0.0005
# 394   0.0005
# 395   0.0005
# 283   0.0005
# Name: count, Length: 436, dtype: float64
#
# Rate/yr(m)
# 15   0.0446
# 27   0.0424
# 33   0.0408
# 42   0.0402
# 30   0.0397
# 35   0.0391
# 14   0.0386
# 16   0.0364
# 22   0.0359
# 41   0.0353
# 17   0.0353
# 13   0.0337
# 20   0.0337
# 25   0.0337
# 18   0.0337
# 32   0.0332
# 37   0.0326
# 28   0.0310
# 36   0.0304
# 26   0.0304
# 39   0.0299
# 40   0.0299
# 29   0.0293
# 38   0.0288
# 21   0.0283
# 19   0.0283
# 34   0.0277
# 31   0.0261
# 24   0.0261
# 23   0.0250
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3500   0.0223
# 3525   0.0207
# 3537   0.0196
# 3521   0.0179
# 3538   0.0179
#         ...
# 3539   0.0103
# 3567   0.0082
# 3502   0.0082
# 3517   0.0076
# 3496   0.0011
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
