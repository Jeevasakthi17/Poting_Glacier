# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1987.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1987                17794            380          16                3544
# 1     1987                17347              2          36                3560
# 2     1987                17483            265          27                3510
# 3     1987                17409            262          34                3510
# 4     1987                17148            377          37                3545
# ...    ...                  ...            ...         ...                 ...
# 1810  1987                17551              3          33                3550
# 1811  1987                17115            230          26                3528
# 1812  1987                17285            408          29                3526
# 1813  1987                17869            281          30                3501
# 1814  1987                17513            238          14                3498
#
# [1815 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1815, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1815 entries, 0 to 1814
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 1815 non-null   int64
#  1   Maximum length (m))  1815 non-null   int64
#  2   Recession(m),        1815 non-null   int64
#  3   Rate/yr(m)           1815 non-null   int64
#  4   Snout altitude (m)   1815 non-null   int64
# dtypes: int64(5)
# memory usage: 71.0 KB

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1815

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1987                17794            380          16                3544
# 1  1987                17347              2          36                3560
# 2  1987                17483            265          27                3510
# 3  1987                17409            262          34                3510
# 4  1987                17148            377          37                3545

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000        -0.0135      0.0089
# Recession(m),         NaN              -0.0135         1.0000      0.0165
# Rate/yr(m)            NaN               0.0089         0.0165      1.0000
# Snout altitude (m)    NaN               0.0204         0.0513     -0.0238
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))              0.0204
# Recession(m),                    0.0513
# Rate/yr(m)                      -0.0238
# Snout altitude (m)               1.0000

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,815.0000           1,815.0000     1,815.0000  1,815.0000  \
# mean  1,987.0000          17,544.7873       223.2446     27.5152
# std       0.0000             294.1517       129.0364      8.6554
# min   1,987.0000          17,035.0000         0.0000     13.0000
# 25%   1,987.0000          17,291.5000       110.5000     20.0000
# 50%   1,987.0000          17,549.0000       221.0000     27.0000
# 75%   1,987.0000          17,794.0000       338.0000     35.0000
# max   1,987.0000          18,065.0000       440.0000     42.0000
#
#        Snout altitude (m)
# count          1,815.0000
# mean           3,531.3537
# std               20.2039
# min            3,496.0000
# 25%            3,514.0000
# 50%            3,531.0000
# 75%            3,548.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1987   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 235   0.0061
# 342   0.0061
# 436   0.0055
# 429   0.0050
# 199   0.0050
#        ...
# 399   0.0006
# 406   0.0006
# 248   0.0006
# 13    0.0006
# 213   0.0006
# Name: count, Length: 432, dtype: float64
#
# Rate/yr(m)
# 26   0.0452
# 42   0.0419
# 18   0.0413
# 23   0.0408
# 20   0.0402
# 41   0.0375
# 32   0.0375
# 36   0.0369
# 19   0.0364
# 27   0.0353
# 14   0.0347
# 37   0.0342
# 22   0.0342
# 35   0.0336
# 30   0.0331
# 24   0.0325
# 39   0.0325
# 15   0.0325
# 25   0.0314
# 16   0.0309
# 29   0.0298
# 31   0.0298
# 33   0.0292
# 38   0.0287
# 21   0.0275
# 17   0.0275
# 13   0.0270
# 40   0.0270
# 34   0.0259
# 28   0.0253
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3506   0.0226
# 3514   0.0209
# 3532   0.0204
# 3534   0.0193
# 3512   0.0193
#         ...
# 3556   0.0094
# 3533   0.0088
# 3507   0.0083
# 3540   0.0083
# 3496   0.0033
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
