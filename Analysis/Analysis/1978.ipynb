# %%
import numpy as np
import pandas as pd

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("1978.xlsx")
df
# Out:
#       Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0     1978                17716            220          39                3507
# 1     1978                17542            280          16                3548
# 2     1978                17245             91          19                3497
# 3     1978                17845            236          42                3528
# 4     1978                17190            306          26                3516
# ...    ...                  ...            ...         ...                 ...
# 1909  1978                17544            369          31                3502
# 1910  1978                17663            145          16                3526
# 1911  1978                17646            268          37                3529
# 1912  1978                17726            126          18                3510
# 1913  1978                17721            212          41                3539
#
# [1914 rows x 5 columns]

# %%
print("Shape of dataframe df: {}".format(df.shape))
# Out:
# Shape of dataframe df: (1914, 5)

# %%
categorical = [col for col in df.columns if df[col].dtype=='O']
print('There are {} categorical variables'.format(len(categorical)))
# Out:
# There are 0 categorical variables

# %%
print('Number of unique Model Names: ', len(df['Snout altitude (m)'].unique()))
print('Number  of instances of models: ', len(df))
# Out:
# Number of unique Model Names:  72
# Number  of instances of models:  1914

# %%
numerical = [col for col in df.columns if df[col].dtype!='O']
print('There are {} numerical variables'.format(len(numerical)))
# Out:
# There are 5 numerical variables

# %%
print(numerical)
# Out:
# ['Year', 'Maximum length (m))', 'Recession(m),', 'Rate/yr(m)', 'Snout altitude (m)']

# %%
df[numerical].head()
# Out:
#    Year  Maximum length (m))  Recession(m),  Rate/yr(m)  Snout altitude (m)
# 0  1978                17716            220          39                3507
# 1  1978                17542            280          16                3548
# 2  1978                17245             91          19                3497
# 3  1978                17845            236          42                3528
# 4  1978                17190            306          26                3516

# %%
pd.options.display.float_format = '{:,.4f}'.format
corr_matrix = df.corr()
corr_matrix
# Out:
#                      Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# Year                  NaN                  NaN            NaN         NaN  \
# Maximum length (m))   NaN               1.0000        -0.0479     -0.0074
# Recession(m),         NaN              -0.0479         1.0000     -0.0053
# Rate/yr(m)            NaN              -0.0074        -0.0053      1.0000
# Snout altitude (m)    NaN               0.0146         0.0081     -0.0788
#
#                      Snout altitude (m)
# Year                                NaN
# Maximum length (m))              0.0146
# Recession(m),                    0.0081
# Rate/yr(m)                      -0.0788
# Snout altitude (m)               1.0000

# %%
corr_matrix['Maximum length (m))'].sort_values(ascending=False)
# Out:
# Maximum length (m))    1.0000
# Snout altitude (m)     0.0146
# Rate/yr(m)            -0.0074
# Recession(m),         -0.0479
# Year                      NaN
# Name: Maximum length (m)), dtype: float64

# %%
plt.figure(figsize=(16,10))
plt.title('Correlation of Attributes with Maximum length (m)) ')
a = sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
df.isnull().sum()
# Out:
# Year                   0
# Maximum length (m))    0
# Recession(m),          0
# Rate/yr(m)             0
# Snout altitude (m)     0
# dtype: int64

# %%
df.describe()
# Out:
#             Year  Maximum length (m))  Recession(m),  Rate/yr(m)
# count 1,914.0000           1,914.0000     1,914.0000  1,914.0000  \
# mean  1,978.0000          17,549.2858       223.4608     27.8563
# std       0.0000             300.2365       125.2132      8.6490
# min   1,978.0000          17,035.0000         0.0000     13.0000
# 25%   1,978.0000          17,286.0000       121.0000     21.0000
# 50%   1,978.0000          17,550.5000       226.0000     28.0000
# 75%   1,978.0000          17,816.7500       329.0000     35.0000
# max   1,978.0000          18,067.0000       440.0000     42.0000
#
#        Snout altitude (m)
# count          1,914.0000
# mean           3,532.2320
# std               20.5192
# min            3,496.0000
# 25%            3,514.0000
# 50%            3,533.0000
# 75%            3,550.0000
# max            3,567.0000

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    print(df[var].value_counts() / np.float(len(df)))
    print()
# Out:
# Year
# 1978   1.0000
# Name: count, dtype: float64
#
# Recession(m),
# 174   0.0068
# 249   0.0057
# 209   0.0057
# 294   0.0057
# 298   0.0052
#        ...
# 281   0.0005
# 420   0.0005
# 14    0.0005
# 74    0.0005
# 311   0.0005
# Name: count, Length: 432, dtype: float64
#
# Rate/yr(m)
# 31   0.0439
# 14   0.0408
# 21   0.0387
# 36   0.0381
# 38   0.0366
# 25   0.0361
# 42   0.0361
# 33   0.0361
# 30   0.0355
# 40   0.0350
# 28   0.0350
# 39   0.0345
# 37   0.0345
# 41   0.0340
# 29   0.0340
# 26   0.0334
# 22   0.0324
# 13   0.0324
# 32   0.0324
# 23   0.0313
# 19   0.0313
# 24   0.0308
# 34   0.0298
# 18   0.0298
# 15   0.0298
# 20   0.0293
# 35   0.0293
# 27   0.0277
# 16   0.0261
# 17   0.0256
# Name: count, dtype: float64
#
# Snout altitude (m)
# 3548   0.0214
# 3553   0.0199
# 3545   0.0183
# 3497   0.0183
# 3509   0.0183
#         ...
# 3544   0.0099
# 3519   0.0094
# 3536   0.0094
# 3515   0.0084
# 3496   0.0005
# Name: count, Length: 72, dtype: float64

# %%
for var in ['Year','Recession(m),','Rate/yr(m)','Snout altitude (m)']:
    plt.figure(figsize=(16,10))
    (df.groupby(var)[var].count() / np.float(len(df))).plot.bar()
    plt.ylabel('Percentage of observations per label')
    plt.title(var)
    plt.show()
